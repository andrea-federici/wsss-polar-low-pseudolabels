# %%
if 'google.colab' in str(get_ipython()):
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd /content/drive/MyDrive/polar-lows-detection-forecasting-deep-learning/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Thesis

# %%
import time
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from tqdm import tqdm

transform = transforms.Compose([
    transforms.CenterCrop(size=(512, 512)),
    transforms.ToTensor()
])

data = datasets.ImageFolder('data/test', transform=transform)

# %%
# SETTINGS

num_workers = 8

# %%
def benchmark_data_loading(dataset, num_workers, batch_size=64):
    data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

    start_time = time.time()
    for batch_idx, (data, target) in enumerate(data_loader):
        pass
    end_time = time.time()

    return end_time - start_time

# %%
elapsed_time = benchmark_data_loading(data, num_workers)
print(f"Number of workers: {num_workers}, Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Number of workers: 16, Elapsed time: 21.93 seconds
