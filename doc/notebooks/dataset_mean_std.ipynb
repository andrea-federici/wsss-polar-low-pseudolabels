# %%
import sys
from pathlib import Path

root = Path('..').resolve()
sys.path.insert(0, str(root))

from torchvision import datasets, transforms

from data_utils import compute_dataset_mean_std
from train_config import train_dir

# %%
train_data = datasets.ImageFolder(
    train_dir('../'), 
    transform=transforms.Compose([
        transforms.Resize((800, 800)),
        transforms.ToTensor()
    ])
)

# %%
compute_dataset_mean_std(train_data)
# Out:
# (tensor([0.2872, 0.2872, 0.4595]), tensor([0.1806, 0.1806, 0.2621]))
